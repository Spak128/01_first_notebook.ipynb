# %%
String_1 = 'Introduction'
String_2 = 'This is my first Jupyter notebook'

print(String_1)
print(String_2)

x = 5
y= 6
z = x+y
print (z)
# Out:
# Introduction
# This is my first Jupyter notebook
# 11
